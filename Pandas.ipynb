# %% [markdown]
# <a href="https://colab.research.google.com/github/BIDS-CPU/data-science1/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 66e3805b8cabe977f40c05259cc3fcf7ead5687d
# python           : 3.7.14.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.133+
# Version          : #1 SMP Fri Aug 26 08:44:51 UTC 2022
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.3.5
# numpy            : 1.21.6
# pytz             : 2022.4
# dateutil         : 2.8.2
# pip              : 21.1.3
# setuptools       : 57.4.0
# Cython           : 0.29.32
# pytest           : 3.6.4
# hypothesis       : None
# sphinx           : 1.8.6
# blosc            : None
# feather          : 0.4.1
# xlsxwriter       : None
# lxml.etree       : 4.9.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : 2.9.4 (dt dec pq3 ext lo64)
# jinja2           : 2.11.3
# IPython          : 7.9.0
# ...

# %%
import numpy as np

p=pd.DataFrame(np.random.rand(6,4))

# %%
p=pd.DataFrame(np.random.rand(6,4),columns=list('asdf'))

# %%
p.columns=['z','x','c','v']

# %%
p
# Out:
#           z         x         c         v
# 0  0.204107  0.720601  0.524428  0.363288
# 1  0.131335  0.027216  0.699967  0.129517
# 2  0.552169  0.686127  0.470969  0.231795
# 3  0.289965  0.380325  0.816845  0.516465
# 4  0.867827  0.618748  0.176601  0.655106
# 5  0.683339  0.557646  0.429646  0.533489

# %%
p=p.rename({'z':'a','c':'b'},axis='columns')

# %%
p.head()
# Out:
#           a         x         b         v
# 0  0.204107  0.720601  0.524428  0.363288
# 1  0.131335  0.027216  0.699967  0.129517
# 2  0.552169  0.686127  0.470969  0.231795
# 3  0.289965  0.380325  0.816845  0.516465
# 4  0.867827  0.618748  0.176601  0.655106

# %%
p.columns=p.columns.str.replace('a','a -')

# %%
p
# Out:
#         a -         x         b         v
# 0  0.204107  0.720601  0.524428  0.363288
# 1  0.131335  0.027216  0.699967  0.129517
# 2  0.552169  0.686127  0.470969  0.231795
# 3  0.289965  0.380325  0.816845  0.516465
# 4  0.867827  0.618748  0.176601  0.655106
# 5  0.683339  0.557646  0.429646  0.533489

# %%
p.add_prefix('xyz-')
# Out:
#     xyz-a -     xyz-x     xyz-b     xyz-v
# 0  0.204107  0.720601  0.524428  0.363288
# 1  0.131335  0.027216  0.699967  0.129517
# 2  0.552169  0.686127  0.470969  0.231795
# 3  0.289965  0.380325  0.816845  0.516465
# 4  0.867827  0.618748  0.176601  0.655106
# 5  0.683339  0.557646  0.429646  0.533489

# %%
p.add_suffix('abc-')
# Out:
#     a -abc-     xabc-     babc-     vabc-
# 0  0.204107  0.720601  0.524428  0.363288
# 1  0.131335  0.027216  0.699967  0.129517
# 2  0.552169  0.686127  0.470969  0.231795
# 3  0.289965  0.380325  0.816845  0.516465
# 4  0.867827  0.618748  0.176601  0.655106
# 5  0.683339  0.557646  0.429646  0.533489

# %%
p.iloc[::-1].reset_index().head(3)
# Out:
#    index       a -         x         b         v
# 0      5  0.683339  0.557646  0.429646  0.533489
# 1      4  0.867827  0.618748  0.176601  0.655106
# 2      3  0.289965  0.380325  0.816845  0.516465

# %%
p.loc[:,::-1].reset_index().head(3)
# Out:
#    index         v         b         x       a -
# 0      0  0.363288  0.524428  0.720601  0.204107
# 1      1  0.129517  0.699967  0.027216  0.131335
# 2      2  0.231795  0.470969  0.686127  0.552169

# %%
p.dtypes
# Out:
# a -    float64
# x      float64
# b      float64
# v      float64
# dtype: object

# %%
p['a']=['a','b','c','d','e','f']

# %%
p.dtypes
# Out:
# a -    float64
# x      float64
# b      float64
# v      float64
# a       object
# dtype: object

# %%
p.select_dtypes(include='number')
# Out:
#         a -         x         b         v
# 0  0.204107  0.720601  0.524428  0.363288
# 1  0.131335  0.027216  0.699967  0.129517
# 2  0.552169  0.686127  0.470969  0.231795
# 3  0.289965  0.380325  0.816845  0.516465
# 4  0.867827  0.618748  0.176601  0.655106
# 5  0.683339  0.557646  0.429646  0.533489

# %%
p.select_dtypes(exclude='number')
# Out:
#    a
# 0  a
# 1  b
# 2  c
# 3  d
# 4  e
# 5  f

# %%
p.a.astype('category')
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# Name: a, dtype: category
# Categories (6, object): ['a', 'b', 'c', 'd', 'e', 'f']

# %%
pd.to_numeric(p.x,errors='coerce')
# Out:
# 0    0.720601
# 1    0.027216
# 2    0.686127
# 3    0.380325
# 4    0.618748
# 5    0.557646
# Name: x, dtype: float64

# %%
p.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a -     6 non-null      float64
#  1   x       6 non-null      float64
#  2   b       6 non-null      float64
#  3   v       6 non-null      float64
#  4   a       6 non-null      object
# dtypes: float64(4), object(1)
# memory usage: 668.0 bytes

# %%
len(p)
# Out:
# 6

# %%
s1=p.sample(frac=0.5)

# %%
s1
# Out:
#         a -         x         b         v  a
# 3  0.289965  0.380325  0.816845  0.516465  d
# 4  0.867827  0.618748  0.176601  0.655106  e
# 0  0.204107  0.720601  0.524428  0.363288  a

# %%
s2=p.drop(s1.index)

# %%
s2
# Out:
#         a -         x         b         v  a
# 1  0.131335  0.027216  0.699967  0.129517  b
# 2  0.552169  0.686127  0.470969  0.231795  c
# 5  0.683339  0.557646  0.429646  0.533489  f

# %%
len(s1)+len(s2)
# Out:
# 6

# %%
s2.x.value_counts()
# Out:
# 0.027216    1
# 0.686127    1
# 0.557646    1
# Name: x, dtype: int64

# %%
s2.nlargest(2,'x')
# Out:
#         a -         x         b         v  a
# 2  0.552169  0.686127  0.470969  0.231795  c
# 5  0.683339  0.557646  0.429646  0.533489  f

# %%
p.groupby('x').agg(['sum','min'])
# Out:
#                a -                   b                   v             a
#                sum       min       sum       min       sum       min sum min
# x
# 0.027216  0.131335  0.131335  0.699967  0.699967  0.129517  0.129517   b   b
# 0.380325  0.289965  0.289965  0.816845  0.816845  0.516465  0.516465   d   d
# 0.557646  0.683339  0.683339  0.429646  0.429646  0.533489  0.533489   f   f
# 0.618748  0.867827  0.867827  0.176601  0.176601  0.655106  0.655106   e   e
# 0.686127  0.552169  0.552169  0.470969  0.470969  0.231795  0.231795   c   c
# 0.720601  0.204107  0.204107  0.524428  0.524428  0.363288  0.363288   a   a

# %%
pd.cut(titanic.Age, bins=[0, 18, 25, 99], labels=['child', 'young adult', 'adult']).head(10)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
format_dict = {'Date':'{:%m/%d/%y}', 'Close':'${:.2f}', 'Volume':'{:,}'}

# %%
stocks.style.format(format_dict)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Date	Close	Volume	Symbol
# 0	10/03/16	$31.50	14,070,500	CSCO
# 1	10/03/16	$112.52	21,701,800	AAPL
# 2	10/03/16	$57.42	19,189,500	MSFT
# 3	10/04/16	$113.00	29,736,800	AAPL
# 4	10/04/16	$57.24	20,085,900	MSFT
# 5	10/04/16	$31.35	18,460,400	CSCO
# 6	10/05/16	$57.64	16,726,400	MSFT
# 7	10/05/16	$31.59	11,808,600	CSCO
# 8	10/05/16	$113.05	21,453,100	AAPL

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-6a23701102c9> in <module>
# ----> 1 pandas_profiling.ProfileReport(p)
#
# /usr/local/lib/python3.7/dist-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# /usr/local/lib/python3.7/dist-packages/pandas_profiling/describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# ...

# %%
df.a.equals(df.b)

# %%
titanic['Sex_num'] = titanic.Sex.map({'male':0, 'female':1})
titanic.Sex_num.head()

# %%
8. Create a cross-tabulation
Sometimes you just want to count the number of observations in each category. If you're interested in a single column, you would use the value_counts() method:

titanic.Sex.value_counts()
male      577
female    314
Name: Sex, dtype: int64

But if you want to count the number of observations that appear in each combination of categories, you would use the crosstab() function:

pd.crosstab(titanic.Sex, titanic.Pclass)
Pclass	1	2	3
Sex			
female	94	76	144
male	122	108	347

# %% [markdown]
# 8. Create a cross-tabulation
# Sometimes you just want to count the number of observations in each category. If you're interested in a single column, you would use the value_counts() method:
#
# titanic.Sex.value_counts()
# male      577
# female    314
# Name: Sex, dtype: int64
# But if you want to count the number of observations that appear in each combination of categories, you would use the crosstab() function:
#
# pd.crosstab(titanic.Sex, titanic.Pclass)
# Pclass	1	2	3
# Sex
# female	94	76	144
# male	122	108	347

# %%
Just like a pivot table, you can include row and column totals by setting margins=True:

pd.crosstab(titanic.Sex, titanic.Pclass, margins=True)
Pclass	1	2	3	All
Sex				
female	94	76	144	314
male	122	108	347	577
All	216	184	491	891

# %%
What if we needed to identify which rows are missing from the second DataFrame? The easiest way to do this would be to merge the two DataFrames using a left join and set indicator=True:

df3 = pd.merge(df1, df2, how='left', indicator=True)
df3
A	B	C	D	_merge
0	0.0	0.0	foo1	2009-01-01	both
1	1.0	1.0	foo2	2009-01-02	both
2	2.0	0.0	foo3	2009-01-05	left_only
3	3.0	1.0	foo4	2009-01-06	left_only
4	4.0	0.0	foo5	2009-01-07	both

# %%
There are three things worth noting about the query() method:

You don't have to repeat the name of the DataFrame within the query string.
The entire condition is expressed as a string, thus you lose any syntax highlighting.
Since there is a string within the condition, you have to use single quotes with the inner string and double quotes with the outer string.

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df=pd.read_csv(url,sep='\t')

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
#  5   r                   4622 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 216.8+ KB

# %%
df.shape[0]
# Out:
# 4622

# %%
df.shape[1]
# Out:
# 5

# %%
df.columns.to_list()
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.groupby('choice_description')['quantity'].sum().sort_values(ascending=False).iloc[0]
# Out:
# 159

# %%
df[['item_name','quantity']].value_counts()
# Out:
# item_name                           quantity
# Chicken Bowl                        1           693
# Chicken Burrito                     1           521
# Chips and Guacamole                 1           455
# Steak Burrito                       1           352
# Canned Soft Drink                   1           264
#                                                ...
# Chips and Guacamole                 3             1
#                                     4             1
# Chips and Mild Fresh Tomato Salsa   1             1
# Chips and Roasted Chili Corn Salsa  2             1
# Veggie Soft Tacos                   2             1
# Length: 103, dtype: int64

# %%
pd.to_numeric(df.item_price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$2.39 "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-67da8e0c60c9> in <module>
# ----> 1 pd.to_numeric(df.item_price)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#     186         except (ValueError, TypeError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.item_price=df.item_price.apply(lambda x:float(x[1:-1]))

# %%
df.item_price=df.item_price.str.replace('$','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.item_price=df.item_price.astype(float)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df['r']=df['item_price']*df['quantity']

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price      r
# 0                                                   NaN        2.39   2.39
# ...

# %%
df.r.sum()
# Out:
# 39237.02

# %%
df.r.mean()
# Out:
# 8.48918649935093

# %%
df.order_id.value_counts().count()
# Out:
# 1834

# %%
df.item_name.nunique()
# Out:
# 50

# %%
df.groupby('order_id')['r'].sum().mean()
# Out:
# 21.39423118865867

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %%
df=pd.read_csv(url,sep='|',index_col='user_id')

# %%
df.head(25)
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# ...

# %%
df.tail(10)
# Out:
#          age gender     occupation zip_code
# user_id
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %%
df.columns.to_list()
# Out:
# ['age', 'gender', 'occupation', 'zip_code']

# %%
df.occupation.nunique()
# Out:
# 21

# %%
df.occupation.value_counts().index[0]
# Out:
# 'student'

# %%
df.describe()
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000

# %%
df.describe(include='all')
# Out:
#                age gender occupation zip_code
# count   943.000000    943        943      943
# unique         NaN      2         21      795
# top            NaN      M    student    55414
# freq           NaN    670        196        9
# mean     34.051962    NaN        NaN      NaN
# std      12.192740    NaN        NaN      NaN
# min       7.000000    NaN        NaN      NaN
# 25%      25.000000    NaN        NaN      NaN
# 50%      31.000000    NaN        NaN      NaN
# 75%      43.000000    NaN        NaN      NaN
# max      73.000000    NaN        NaN      NaN

# %%
round(df.age.mean())
# Out:
# 34

# %%
df.age.value_counts().tail()
# Out:
# 7     1
# 66    1
# 11    1
# 10    1
# 73    1
# Name: age, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
df.columns[2]
# Out:
# 'occupation'

# %%
df.iloc[3][2]
# Out:
# 'technician'

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df=pd.read_csv(url,sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.item_price=df.item_price.apply(lambda x:float(x[1:-1]))

# %%
df.query('item_price>10').item_name
# Out:
# 4             Chicken Bowl
# 5             Chicken Bowl
# 7            Steak Burrito
# 13            Chicken Bowl
# 23         Chicken Burrito
#                ...
# 4610         Steak Burrito
# 4611        Veggie Burrito
# 4617         Steak Burrito
# 4618         Steak Burrito
# 4619    Chicken Salad Bowl
# Name: item_name, Length: 1130, dtype: object

# %%
df[['item_name','item_price']][['quantity']].sort_values(by='item_price',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-4ee125a9a770> in <module>
# ----> 1 df[['item_name','item_price']][['quantity']].sort_values(by='item_price',ascending=False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df.sort_values('item_price',ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
df.item_name.value_counts()['Veggie Salad Bowl']
# Out:
# 18

# %%
len(df.query("item_name=='Canned Soda' and quantity>1"))
# Out:
# 20

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv'

# %%
df=pd.read_csv(url)

# %%
pd.set_option('display.max.columns',None)

# %%
df.head(2)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
#
#    Penalties not scored  Headed goals  Passes  Passes completed  \
# 0                     0             2    1076               828
# 1                     0             0    1565              1223
#
#   Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 0            76.9%     1706       60        42             14       49
# 1            78.1%     2358       46        68             21       62
#
#    Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %%
df.shape
# Out:
# (16, 35)

# %%
df.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
df.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
len(df.columns)
# Out:
# 35

# %%
df.Team.value_counts().count()
# Out:
# 16

# %%
d=df[['Team','Yellow Cards','Red Cards']]

# %%
d.sort_values(by=['Red Cards','Yellow Cards'],ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
d.groupby('Team')['Yellow Cards'].mean()
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %%
df.query("Goals>6")
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                      0             2    2774              2427
# 13                     0             2    4317              3820
#
#    Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5             87.4%     3761      101        60             35       91
# 13            88.4%     5585       69       106             44      122
#
#     Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %%
df[df.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                     0             2    2774              2427
# 6                     1             0    1187               911
#
#   Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5            87.4%     3761      101        60             35       91
# 6            76.7%     2016       52        53             10       65
#
#    Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %%
df.iloc[:,0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
df.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
df[df.Team.isin(['England','Italy','Russia'])][['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Ge']}

# %%
df=pd.DataFrame(raw_data)

# %%
df.head()
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 4    Dragoons     1st      43        4  1592        73          2        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas
# 3          2     Florida
# 4          3       Maine

# %%
df.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %%
df=df.set_index('origin')

# %%
df
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
df[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Ge               345      35

# %%
df.index.value_counts()
# Out:
# Arizona       1
# California    1
# Texas         1
# Florida       1
# Maine         1
# Iowa          1
# Alaska        1
# Washington    1
# Oregon        1
# Wyoming       1
# Louisana      1
# Ge            1
# Name: origin, dtype: int64

# %%
df[df.index.isin(['Maine','Alaska'])][['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
df.iloc[2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %%
df.shape
# Out:
# (12, 9)

# %%
df.iloc[::4,:]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona  Nighthawks     1st     523        5  1045         1          1
# Maine      Dragoons     1st      43        4  1592        73          2
# Oregon       Scouts     1st      62        4   973        48          2
#
#          armored  deserters
# origin
# Arizona        1          4
# Maine          0          3
# Oregon         0          2

# %%
df.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %%
df.query("deaths>500 or deaths<50")
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Ge            Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Ge              1          3

# %%
df.query("regiment!='Dragoons'")
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Ge              Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# ...

# %%
df.loc[['Texas','Arizona'],:]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %%
df.loc['Arizona'][2]
# Out:
# 523

# %%
df.loc[:,['deaths']].iloc[2]
# Out:
# deaths    25
# Name: Texas, dtype: int64

# %%
u='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %%
df=pd.read_csv(u)

# %%
df.sample(3)
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 9       Austria            279               75            191
# 18        Benin             34                4             13
# 168  Tajikistan              2               15              0
#
#      total_litres_of_pure_alcohol continent
# 9                             9.7        EU
# 18                            1.1        AF
# 168                           0.3        AS

# %%
df.shape
# Out:
# (193, 6)

# %%
df.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
df.groupby(['continent'])['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
df.groupby('continent').mean()['total_litres_of_pure_alcohol']
# Out:
# continent
# AF    3.007547
# AS    2.170455
# EU    8.617778
# OC    3.381250
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
df.groupby('continent').spirit_servings.agg({'min','max','sum'})
# Out:
#             sum  max  min
# continent
# AF          866  152    0
# AS         2677  326    0
# EU         5965  373    0
# OC          935  254    0
# SA         1377  302   25

# %%
u='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %%
df=pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')

# %%
df.head(2)
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043

# %%
df.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
df.occupation.value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
df.gender.sum()
# Out:
# 670

# %%
df.gender=df.gender.map({'M':1,'F':0})

# %%
df.groupby('occupation').gender.sum()/df.occupation.value_counts()*100
# Out:
# administrator     54.430380
# artist            53.571429
# doctor           100.000000
# educator          72.631579
# engineer          97.014925
# entertainment     88.888889
# executive         90.625000
# healthcare        31.250000
# homemaker         14.285714
# lawyer            83.333333
# librarian         43.137255
# marketing         61.538462
# none              55.555556
# other             65.714286
# programmer        90.909091
# retired           92.857143
# salesman          75.000000
# scientist         90.322581
# student           69.387755
# technician        96.296296
# writer            57.777778
# dtype: float64

# %%
df.groupby('occupation')['gender'].value_counts(normalize=True)
# Out:
# occupation     gender
# administrator  M         0.544304
#                F         0.455696
# artist         M         0.535714
#                F         0.464286
# doctor         M         1.000000
# educator       M         0.726316
#                F         0.273684
# engineer       M         0.970149
#                F         0.029851
# entertainment  M         0.888889
#                F         0.111111
# executive      M         0.906250
#                F         0.093750
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         M         0.833333
#                F         0.166667
# librarian      F         0.568627
#                M         0.431373
# marketing      M         0.615385
#                F         0.384615
# none           M         0.555556
#                F         0.444444
# other          M         0.657143
#                F         0.342857
# ...

# %%
d = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70,62,70]}

# %%
df=pd.DataFrame(d)

# %%
df.head(2)
# Out:
#      regiment company      name  preTestScore  postTestScore
# 0  Nighthawks     1st    Miller             4             25
# 1  Nighthawks     1st  Jacobson            24             94

# %%
df.loc[df['regiment']=='Nighthawks'].groupby('regiment').mean()
# Out:
#             preTestScore  postTestScore
# regiment
# Nighthawks         15.25           59.5

# %%
df.groupby('company')['preTestScore'].mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'

# %%
df=pd.read_csv(url)

# %%
df.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home    other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# 0         no     yes    yes       no       no       4         3      4     1
# 1         no      no    yes      yes       no       5         3      3     1
#
#    Walc  health  absences  G1  G2  G3
# 0     1       3         6   5   6   6
# 1     1       3         4   5   5   6

# %%
df.loc[:,'school':'guardian']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %%
df.Mjob=df.Mjob.str.capitalize()

# %%
df['d']=df.age.apply(lambda x:'yes' if x>18 else 'no')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     other
# 2       GP   F   15       U     LE3       T     1     1   At_home     other
# 3       GP   F   15       U     GT3       T     4     2    Health  services
# 4       GP   F   16       U     GT3       T     3     3     Other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  services
# 391     MS   M   17       U     LE3       T     3     1  Services  services
# 392     MS   M   21       R     GT3       T     1     1     Other     other
# 393     MS   M   18       R     LE3       T     3     2  Services     other
# 394     MS   M   19       U     LE3       T     1     1     Other   at_home
#
# ...

# %%
df.select_dtypes(include='number')*10
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    180    40    40          20         20         0      40        30
# 1    170    10    10          10         20         0      50        30
# 2    150    10    10          10         20        30      40        30
# 3    150    40    20          10         30         0      30        20
# 4    160    30    30          10         20         0      40        30
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390  200    20    20          10         20        20      50        50
# 391  170    30    10          20         10         0      20        40
# 392  210    10    10          10         10        30      50        50
# 393  180    30    20          30         10         0      40        40
# 394  190    10    10          10         10         0      30        20
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3
# ...

# %%
import numpy as np

# %%
u= "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv"

# %%
df=pd.read_csv(u)

# %%
df.head(3)
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
df['Year']=pd.to_datetime(df['Year'],format='%Y')

# %%
df=df.set_index(df['Year'],drop=True)

# %%
df.drop('Year',axis=1)
# Out:
#     Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0    179323175   3384200   288460   3095700    9110          17190   107840
# 1    182992000   3488000   289390   3198600    8740          17220   106670
# 2    185771000   3752200   301510   3450700    8530          17550   110860
# 3    188483000   4109500   316970   3792500    8640          17650   116470
# 4    191141000   4564600   364220   4200400    9360          21420   130390
# 5    193526000   4739400   387390   4352000    9960          23410   138690
# 6    195576000   5223500   430180   4793300   11040          25820   157990
# 7    197457000   5903400   499930   5403500   12240          27620   202910
# 8    199399000   6720200   595010   6125200   13800          31670   262840
# 9    201385000   7410900   661870   6749000   14760          37170   298850
# 10   203235298   8098000   738820   7359200   16000          37990   349860
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
df.drop('Year',inplace=True,axis=1)

# %%
df.head().append(df.tail())
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 2010-01-01   309330219  10363873  1251248   9112625   14772          85593
# 2011-01-01   311587816  10258774  1206031   9052743   14661          84175
# 2012-01-01   313873685  10219059  1217067   9001992   14866          85141
# 2013-01-01   316497531   9850445  1199684   8650761   14319          82109
# 2014-01-01   318857056   9475816  1197987   8277829   14249          84041
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# ...

# %%
df.resample('10y').mean().head(3)
# Out:
#              Population       Total    Violent   Property   Murder  \
# Year
# 1960-12-31  179323175.0   3384200.0   288460.0  3095700.0   9110.0
# 1970-12-31  193896529.8   5400970.0   458529.0  4942440.0  11307.0
# 1980-12-31  214330726.4  10630190.0  1021363.0  9608830.0  19927.0
#
#             Forcible_Rape   Robbery  Aggravated_assault   Burglary  \
# Year
# 1960-12-31        17190.0  107840.0            154320.0   912100.0
# 1970-12-31        25752.0  187553.0            233917.0  1461400.0
# 1980-12-31        59957.0  437500.0            503980.0  3007620.0
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1960-12-31      1855400.0       328200.0
# 1970-12-31      2891810.0       589230.0
# 1980-12-31      5606890.0       994320.0

# %%
df.resample('m').sum().head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-31   179323175  3384200   288460   3095700    9110          17190
# 1960-02-29           0        0        0         0       0              0
# 1960-03-31           0        0        0         0       0              0
# 1960-04-30           0        0        0         0       0              0
# 1960-05-31           0        0        0         0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-31   107840              154320    912100        1855400
# 1960-02-29        0                   0         0              0
# 1960-03-31        0                   0         0              0
# 1960-04-30        0                   0         0              0
# 1960-05-31        0                   0         0              0
#
#             Vehicle_Theft
# Year
# 1960-01-31         328200
# 1960-02-29              0
# ...

# %%
df.idxmax()
# Out:
# Population           2014-01-01
# Total                1991-01-01
# Violent              1992-01-01
# Property             1991-01-01
# Murder               1991-01-01
# Forcible_Rape        1992-01-01
# Robbery              1991-01-01
# Aggravated_assault   1993-01-01
# Burglary             1980-01-01
# Larceny_Theft        1991-01-01
# Vehicle_Theft        1991-01-01
# dtype: datetime64[ns]

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df=pd.read_csv(url,sep='\t')

# %%
df.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
import matplotlib.pyplot as plt

# %%
df.item_name.value_counts().head(5).plot(kind='bar',title='Top 5 items')

# %%
df.item_price=df.item_price.apply(lambda x:float(x[1:-1]))

# %%
o=df.groupby('order_id').sum()

# %%
plt.scatter(x=df.item_price,y=df.quantity)

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73], 
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}

df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'female', 'preTestScore', 'postTestScore'])

df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
plt.scatter(df.preTestScore, df.postTestScore, s=df.age)

#set labels and titles
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('preTestScore')
# Out:
# Text(0, 0.5, 'preTestScore')

# %%
plt.scatter(df.preTestScore, df.postTestScore, s= df.postTestScore * 4.5, c = df.female)

#set labels and titles
plt.title("preTestScore x postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('preTestScore')
# Out:
# Text(0, 0.5, 'preTestScore')

# %%
l = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv'

# %%
df=pd.read_csv(l)

# %%
df.head(2)
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
df=df.set_index('Date')

# %%
df.index.is_unique
# Out:
# True

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
df.sort_index(ascending=True).head(3)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39

# %%
df.resample('BM').min()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 1980-12-31   25.37   25.37   25.25   25.25   8937600       0.39
# 1981-01-30   28.50   28.50   28.25   28.25   2805600       0.44
# 1981-02-27   24.00   24.00   23.75   23.75   1982400       0.37
# 1981-03-31   21.87   21.87   21.62   21.62   1344000       0.34
# 1981-04-30   24.38   24.38   24.25   24.25   1663200       0.38
# ...            ...     ...     ...     ...       ...        ...
# 2014-03-31  523.42  529.97  522.81  524.69  42167300      74.54
# 2014-04-30  518.05  521.09  511.33  517.96  40586000      73.58
# 2014-05-30  584.54  586.25  580.33  585.54  39934300      83.65
# 2014-06-30   90.21   90.70   89.65   90.28  29689800      89.81
# 2014-07-31   93.52   94.06   93.09   93.48  22891800      93.48
#
# [404 rows x 6 columns]
