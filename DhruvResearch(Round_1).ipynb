# %% [markdown]
# <a href="https://colab.research.google.com/github/BIDS-CPU/data-science1/blob/main/DhruvResearch(Round_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("DA Drive Assignment (2) (2).xlsx - dataset.csv")

# %%
df.head()
# Out:
#               submission_id      submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9.140540e+09     224
# 1  610b639e506b3b060c006dc4  2021-08-05 08:18:39  9.627410e+09      82
# 2  610b6bc0eb775806058eb59b  2021-08-05 09:38:57  9.997932e+09      82
# 3  610b759f1c1bbf76f6f5a496  2021-08-05 09:32:10  8.840877e+09     324
# 4  610b7851eb775806058ebcb9  2021-08-05 10:42:35  9.678869e+09     324
#
#           AC   age  gender religion ls_19         vs_17  \
# 0  मऊरानीपुर  28.0    Male    Hindu   BJP  Did Not Vote
# 1       मांट  53.0    Male    Hindu   BJP           BSP
# 2       मांट  24.0    Male    Hindu   BJP           BJP
# 3    सहजनवां  30.0    Male    Hindu   MGB           BSP
# 4    सहजनवां  19.0  Female    Hindu   BJP  Did Not Vote
#
#                           caste                               monthly_income  \
# 0                   कोरी (Kori)  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)
# ...

# %%
##Create a new dataframe that has the samples where votes in ls_19 were given to BJP. Thereafter, Find the AC where BJP got most number of votes.

# %%
df.shape
# Out:
# (2000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   submission_id     2000 non-null   object
#  1   submission_date   2000 non-null   object
#  2   ph_num            1960 non-null   float64
#  3   AC_num            2000 non-null   int64
#  4   AC                2000 non-null   object
#  5   age               1972 non-null   float64
#  6   gender            1987 non-null   object
#  7   religion          1972 non-null   object
#  8   ls_19             1952 non-null   object
#  9   vs_17             1957 non-null   object
#  10  caste             1961 non-null   object
#  11  monthly_income    1972 non-null   object
#  12  occupation        1960 non-null   object
#  13  satisfation_cm    1958 non-null   object
#  14  satisfation_PM    1958 non-null   object
#  15  mla_satisfaction  1562 non-null   object
# ...

# %%
df.describe()
# Out:
#              ph_num       AC_num          age
# count  1.960000e+03  2000.000000  1972.000000
# mean   8.635482e+09   197.609500    39.130325
# std    1.077027e+09   110.569412    13.932276
# min    6.261694e+09     8.000000    18.000000
# 25%    7.817743e+09   110.000000    28.000000
# 50%    8.893513e+09   188.000000    36.000000
# 75%    9.628182e+09   296.000000    50.000000
# max    9.999492e+09   402.000000    85.000000

# %%
df.convert_dtypes()
# Out:
#                  submission_id      submission_date      ph_num  AC_num  \
# 0     610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9140539696     224
# 1     610b639e506b3b060c006dc4  2021-08-05 08:18:39  9627410417      82
# 2     610b6bc0eb775806058eb59b  2021-08-05 09:38:57  9997931643      82
# 3     610b759f1c1bbf76f6f5a496  2021-08-05 09:32:10  8840877099     324
# 4     610b7851eb775806058ebcb9  2021-08-05 10:42:35  9678869067     324
# ...                        ...                  ...         ...     ...
# 1995  612a51e51a296b33ec8db294  2021-08-28 09:04:52  8052279598     296
# 1996  612a51e61a296b33ec8db2b8  2021-08-28 17:59:51  7800899045     296
# 1997  612a551b910d9633c93482cc  2021-08-28 11:22:44  8853965460     305
# 1998  612a552e1a296b33ec8db8e7  2021-08-28 10:14:38  8400709025     305
# 1999  612a552f1a296b33ec8db905  2021-08-28 18:17:51  7379767635     305
#
#              AC  age  gender religion         ls_19            vs_17  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   submission_id     2000 non-null   object
#  1   submission_date   2000 non-null   object
#  2   ph_num            1960 non-null   float64
#  3   AC_num            2000 non-null   int64
#  4   AC                2000 non-null   object
#  5   age               1972 non-null   float64
#  6   gender            1987 non-null   object
#  7   religion          1972 non-null   object
#  8   ls_19             1952 non-null   object
#  9   vs_17             1957 non-null   object
#  10  caste             1961 non-null   object
#  11  monthly_income    1972 non-null   object
#  12  occupation        1960 non-null   object
#  13  satisfation_cm    1958 non-null   object
#  14  satisfation_PM    1958 non-null   object
#  15  mla_satisfaction  1562 non-null   object
# ...

# %%
##Create a new dataframe that has the samples where votes in ls_19 were given to BJP. Thereafter, Find the AC where BJP got most number of votes.

# %%
df.head(1)
# Out:
#               submission_id      submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव

# %%
q1=df.loc[df['ls_19']=='BJP']

# %%
q1.groupby('AC').sum()['AC_num'].sort_values(ascending=False).to_frame()
# Out:
#            AC_num
# AC
# कपिलवस्तु    6060
# ओबरा         5628
# शिवपुर       5404
# फाजिलनगर     5312
# मऊरानीपुर    4928
# ...           ...
# कैराना        136
# Bhojipura     120
# बड़ौत         102
# लोनी           53
# चांदपुर        23
#
# [120 rows x 1 columns]

# %%
q1.groupby('AC').sum().iloc[1].to_frame()
# Out:
#            Bhojipura
# ph_num  8.057173e+09
# AC_num  1.200000e+02
# age     5.100000e+01

# %%
##Extract individual dates from the submission_date column. Hence plot a bar graph of the count of samples on individual dates

# %%
df.head(1)
# Out:
#               submission_id      submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव

# %%
df['submission_date']=pd.to_datetime(df['submission_date'])

# %%
df.dtypes
# Out:
# submission_id               object
# submission_date     datetime64[ns]
# ph_num                     float64
# AC_num                       int64
# AC                          object
# age                        float64
# gender                      object
# religion                    object
# ls_19                       object
# vs_17                       object
# caste                       object
# monthly_income              object
# occupation                  object
# satisfation_cm              object
# satisfation_PM              object
# mla_satisfaction            object
# mla_choice                  object
# cm_choice                   object
# date                        object
# hour                         int64
# dtype: object

# %%
df['date']=df['submission_date'].dt.date

# %%
q2=df.date.value_counts().to_frame()
q2
# Out:
#             date
# 2021-08-28   160
# 2021-08-27   144
# 2021-08-25   138
# 2021-08-21   134
# 2021-08-24   133
# 2021-08-19   132
# 2021-08-26   132
# 2021-08-10   122
# 2021-08-09   114
# 2021-08-20   112
# 2021-08-23   102
# 2021-08-18    88
# 2021-08-16    73
# 2021-08-17    71
# 2021-08-11    67
# 2021-08-12    49
# 2021-08-14    42
# 2021-08-08    41
# 2021-08-06    39
# 2021-08-05    37
# 2021-08-13    36
# 2021-08-07    34

# %%
q2.plot(kind='bar')

# %%
##List the number of samples that were brought in after 12 pm on 2021-08-24.

# %%
df.head(2)
# Out:
#               submission_id      submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755  2021-08-05 09:10:20  9.140540e+09     224
# 1  610b639e506b3b060c006dc4  2021-08-05 08:18:39  9.627410e+09      82
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
# 1       मांट  53.0   Male    Hindu   BJP           BSP    नाई (Nai)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
# 1   बीपीएल/5,000 रु. से कम (BPL/Below ₹ 5,000)  निजी सेवा (प्राइवेट सर्विस)
#
#          satisfation_cm        satisfation_PM   mla_satisfaction  \
# 0    कुछ हद तक असंतुष्ट    कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
# 1  पूरी तरह से असंतुष्ट  पूरी तरह से असंतुष्ट   पूरी तरह संतुष्ट
#
#                       mla_choice       cm_choice
# 0    भाजपा - श्री बिहारीलाल आर्य     अखिलेश यादव
# ...

# %%
df['hour']=df['submission_date'].dt.hour

# %%
df.hour
# Out:
# 0        9
# 1        8
# 2        9
# 3        9
# 4       10
#         ..
# 1995     9
# 1996    17
# 1997    11
# 1998    10
# 1999    18
# Name: hour, Length: 2000, dtype: int64

# %%
q3=df.query("date==2021-08-24")
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-152-3f4833168cdc>", line 1, in <module>
#     q3=df.query("date==2021-08-24")
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/frame.py", line 4060, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/frame.py", line 4191, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/computation/eval.py", line 348, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py", line 806, in __init__
#     self.terms = self.parse()
#
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/computation/expr.py", line 825, in parse
# ...

# %%
q3
# Out:
# Empty DataFrame
# Columns: [submission_id, submission_date, ph_num, AC_num, AC, age, gender, religion, ls_19, vs_17, caste, monthly_income, occupation, satisfation_cm, satisfation_PM, mla_satisfaction, mla_choice, cm_choice, date, hour]
# Index: []

# %%
##Find out the correlation between CM Satisfaction and PM Satisfaction.

# %%
df.head(1)
# Out:
#               submission_id     submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755 2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice  date  hour
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव     5     9

# %%
q4=df[['satisfation_cm','satisfation_PM']]

# %%
q4.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
##Create a pivot table to find out the % of votes given by individual religions to all the parties in vs_17.

# %%
df.head(1)
# Out:
#               submission_id     submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755 2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice  date  hour
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव     5     9

# %%
q=pd.pivot_table(index=)

# %%
##Find out the percentage of NA values in each column.

# %%
q5=df.isnull().sum()
q5.value_counts(normalize=True).to_frame()
# Out:
#         0
# 0    0.30
# 28   0.15
# 40   0.10
# 42   0.10
# 13   0.05
# 48   0.05
# 43   0.05
# 39   0.05
# 438  0.05
# 45   0.05
# 46   0.05

# %%
q5['null']=q5.isnull()/len(df)
q5.null
# Out:
# submission_id       0.0
# submission_date     0.0
# ph_num              0.0
# AC_num              0.0
# AC                  0.0
# age                 0.0
# gender              0.0
# religion            0.0
# ls_19               0.0
# vs_17               0.0
# caste               0.0
# monthly_income      0.0
# occupation          0.0
# satisfation_cm      0.0
# satisfation_PM      0.0
# mla_satisfaction    0.0
# mla_choice          0.0
# cm_choice           0.0
# date                0.0
# hour                0.0
# null                0.0
# dtype: float64

# %%
##Find out the percentage of unemployed females and did not vote in vs_17.

# %%
df.head(1)
# Out:
#               submission_id     submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755 2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice  date  hour
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव     5     9

# %%
df.columns
# Out:
# Index(['submission_id', 'submission_date', 'ph_num', 'AC_num', 'AC', 'age',
#        'gender', 'religion', 'ls_19', 'vs_17', 'caste', 'monthly_income',
#        'occupation', 'satisfation_cm', 'satisfation_PM', 'mla_satisfaction',
#        'mla_choice', 'cm_choice', 'date', 'hour'],
#       dtype='object')

# %%
q6=df.query("gender=='Female' and vs_17=='Did Not Vote'")
len(q6)
# Out:
# 47

# %%
len(q6)/len(df)
# Out:
# 0.0235

# %%
q6
# Out:
#                  submission_id     submission_date        ph_num  AC_num  \
# 4     610b7851eb775806058ebcb9 2021-08-05 10:42:35  9.678869e+09     324
# 44    610cdb9aa32d6e798185b2c7 2021-08-06 11:53:17  9.690070e+09      22
# 56    610d1dbe5c62e3797b5f343d 2021-08-06 16:24:51  8.736815e+09     364
# 204   6111062c8f8d85496ec04e3b 2021-08-09 12:10:31  7.704059e+09     307
# 211   611113bca38a66494208cfdc 2021-08-09 16:20:26  7.607974e+09     170
# 294   611228bf7649c85fdd059592 2021-08-10 09:28:01  8.604357e+09     170
# 325   61125293cb5b8127b19728ee 2021-08-10 15:32:53  7.897825e+09     170
# 348   611279c5a175f7671ed4b155 2021-08-10 15:52:02  7.715897e+09     307
# 371   61128f2670563f6744edc8e6 2021-08-10 17:27:27  9.519704e+09     182
# 484   61151537c05d402944b1bd40 2021-08-12 17:43:02  9.558177e+09     364
# 514   611632f7e0a7702916c16f02 2021-08-13 13:58:56  8.176941e+09     149
# 550   61177b30c2fbb559414bb5eb 2021-08-14 08:24:34  7.500977e+09      94
# ...

# %%
##Create a pie chart showcasing the number of votes obtained by each party in ls_19.

# %%
df.head(1)
# Out:
#               submission_id     submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755 2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice  date  hour
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव     5     9

# %%
df.ls_19
# Out:
# 0                BJP
# 1                BJP
# 2                BJP
# 3                MGB
# 4                BJP
#             ...
# 1995    Did Not Vote
# 1996             MGB
# 1997             BJP
# 1998             BJP
# 1999             BJP
# Name: ls_19, Length: 2000, dtype: object

# %%
from pandas.plotting import autocorrelation_plot

q7=df.groupby("vs_17")['ls_19'].count().plot(kind='pie',autopct = '%1.1f%%')

# %%
df.head(1)
# Out:
#               submission_id     submission_date        ph_num  AC_num  \
# 0  610b61421c1bbf76f6f59755 2021-08-05 09:10:20  9.140540e+09     224
#
#           AC   age gender religion ls_19         vs_17        caste  \
# 0  मऊरानीपुर  28.0   Male    Hindu   BJP  Did Not Vote  कोरी (Kori)
#
#                                 monthly_income                   occupation  \
# 0  5,000 रु. - 10,000 रु. (₹ 5,000 - ₹ 10,000)  निजी सेवा (प्राइवेट सर्विस)
#
#        satisfation_cm      satisfation_PM   mla_satisfaction  \
# 0  कुछ हद तक असंतुष्ट  कुछ हद तक असंतुष्ट  कुछ हद तक संतुष्ट
#
#                     mla_choice    cm_choice  date  hour
# 0  भाजपा - श्री बिहारीलाल आर्य  अखिलेश यादव     5     9

# %%
sqlq1=select * from df where mla_choice in ('SP','BJP','BSP');

# %%
##Write a SQL query to return all the details of those entries in the dataset where phone number (ph_num) is duplicated.

# %%
sq1q2= select count(*),ph_num  from df group by ph_num having count(*)>1;
